# %% [markdown]
# A simple problem demonstrating **NTFk** can be executed as follows.
#
# First, generate a random Tucker tensor:

# %%
import NTFk
import TensorDecompositions

csize = (2, 3, 4)
tsize = (5, 10, 15)
tucker_orig = NTFk.rand_tucker(csize, tsize; factors_nonneg=true, core_nonneg=true)
# Out:
# ┌ Info: Recompiling stale cache file /Users/monty/.julia/compiled/v1.2/NTFk/BitEf.ji for NTFk [1226e131-0b97-51f8-8a3f-c1798118cd52]
# └ @ Base loading.jl:1240
# ┌ Warning: PyPlot is using tkagg backend, which is known to cause crashes on MacOS (#410); use the MPLBACKEND environment variable to request a different backend.
# └ @ PyPlot ~/.julia/packages/PyPlot/4wzW1/src/init.jl:192
# WARNING: using HTTP.stack in module Mux conflicts with an existing identifier.
# WARNING: Method definition savehtml(IO, PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:40 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:334.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition savehtml(PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace, AbstractString) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:52 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:361.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition savehtml(IO, PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:40 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:334.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition savehtml(PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace, AbstractString) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:52 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:361.
#   ** incremental compilation may be fatally broken for this module **
# NMFk: Nonnegative Matrix Factorization + k-means clustering
# ====
#
#   _     _   _      _   _______   _
#  |  \  | | |  \  /  | |  _____| | |  _
#  | . \ | | | . \/ . | | |___    | | / /
#  | |\ \| | | |\  /| | |  ___|   | |/ /
#  | | \ ' | | | \/ | | | |       |   (
#  | |  \  | | |    | | | |       | |\ \
#  |_|   \_| |_|    |_| |_|       |_| \_\
#
# NMFk performs unsupervised machine learning based on matrix decomposition coupled with sparsity and nonnegativity constraints.
# NMFk methodology allows for automatic identification of the optimal number of features (signals) present in two-dimensional data arrays (matrices).
# The number of features is estimated automatically.
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for NMFk [e40cd9e2-a1df-5d90-a1fa-603fdc3dbdd8]
# │   exception = Required dependency JuMP [4076af6c-e467-56ae-b986-b466b2749572] failed to load from a cache file.
# └ @ Base loading.jl:1025
# ┌ Warning: PyPlot is using tkagg backend, which is known to cause crashes on MacOS (#410); use the MPLBACKEND environment variable to request a different backend.
# └ @ PyPlot ~/.julia/packages/PyPlot/4wzW1/src/init.jl:192
# WARNING: Method definition savehtml(IO, PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:40 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:334.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition savehtml(PlotlyBase.Plot{TT} where TT<:PlotlyBase.AbstractTrace, AbstractString) in module PlotlyBase at /Users/monty/.julia/packages/PlotlyBase/80KwD/src/output.jl:52 overwritten in module PlotlyJS at /Users/monty/.julia/packages/PlotlyJS/b9Efu/src/display.jl:361.
#   ** incremental compilation may be fatally broken for this module **
# NMFk: Nonnegative Matrix Factorization + k-means clustering
# ====
#
#   _     _   _      _   _______   _
#  |  \  | | |  \  /  | |  _____| | |  _
#  | . \ | | | . \/ . | | |___    | | / /
#  | |\ \| | | |\  /| | |  ___|   | |/ /
#  | | \ ' | | | \/ | | | |       |   (
#  | |  \  | | |    | | | |       | |\ \
#  |_|   \_| |_|    |_| |_|       |_| \_\
#
# NMFk performs unsupervised machine learning based on matrix decomposition coupled with sparsity and nonnegativity constraints.
# NMFk methodology allows for automatic identification of the optimal number of features (signals) present in two-dimensional data arrays (matrices).
# The number of features is estimated automatically.
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `git@github.com:JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/dev/NTFk/Project.toml`
#   [7d9fca2a] + Arpack v0.3.1
#   [7f9c7709] + BIGUQ v0.6.0
#   [6c57e878] + CanDecomp v0.1.1
#   [5ae59095] + Colors v0.9.6
#   [a81c6b42] + Compose v0.7.3
#   [8f4d0f93] + Conda v1.3.0
#   [aaf54ef3] + DistributedArrays v0.6.4
#   [31c24e10] + Distributions v0.21.3
#   [e1f3b4f0] + DocumentFunction v0.5.1
#   [5789e2e9] + FileIO v1.0.7
#   [c91e804a] + Gadfly v1.0.1
#   [0ef565a4] + Geodesy v0.5.0
#   [916415d5] + Images v0.18.0
#   [a98d9a8b] + Interpolations v0.12.2
#   [b6b21f68] + Ipopt v0.6.1
#   [4138dd39] + JLD v0.9.1
#   [033835bb] + JLD2 v0.1.3
#   [4076af6c] + JuMP v0.20.1
#   [bae27b42] + LoadTensorDecompositions v0.1.0
#   [10e44e05] + MATLAB v0.7.3
#   [442fdcdd] + Measures v0.3.0
#   [e40cd9e2] + NMFk v0.1.8
#   [438e738f] + PyCall v1.91.2
#   [d330b81b] + PyPlot v2.8.2
#   [04ed911b] + TensorDecompositions v1.0.0
#   [6aa20fa7] + TensorOperations v1.3.1
#   [9c690861] + TensorToolbox v1.0.1
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [37e2e46d] + LinearAlgebra
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   Updating `~/.julia/dev/NTFk/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.4.1
#   [79e6a3ab] + Adapt v1.0.0
#   [a0f608ac] + AffineInvariantMCMC v0.5.0
#   [fd9e7046] + Anasol v0.5.3
#   [ec485272] + ArnoldiMethod v0.0.4
#   [7d9fca2a] + Arpack v0.3.1
#   [4fba245c] + ArrayInterface v1.2.1
#   [bf4720bc] + AssetRegistry v0.1.0
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [39de3d68] + AxisArrays v0.3.3
#   [7f9c7709] + BIGUQ v0.6.0
#   [aae01518] + BandedMatrices v0.12.4
#   [6e4b80f9] + BenchmarkTools v0.4.3
#   [9e28174c] + BinDeps v0.8.10
#   [b99e7846] + BinaryProvider v0.5.7
#   [a134a8b2] + BlackBoxOptim v0.5.0
#   [ad839575] + Blink v0.12.0
#   [8e7c35d0] + BlockArrays v0.10.1
#   [ffab5731] + BlockBandedMatrices v0.5.1
#   [a74b3585] + Blosc v0.5.1
#   [631607c0] + CMake v1.1.2
#   [d5fb7624] + CMakeWrapper v0.2.3
#   [a9c8d775] + CPUTime v1.0.0
#   [00ebfdb7] + CSTParser v0.6.2
#   [159f3aea] + Cairo v0.8.0
#   [49dc2e85] + Calculus v0.5.0
#   [6c57e878] + CanDecomp v0.1.1
#   [aafaddc9] + CatIndices v0.2.0
#   [324d7699] + CategoricalArrays v0.7.1
#   [aaaa29a8] + Clustering v0.13.3
#   [944b1d66] + CodecZlib v0.6.0
#   [19ecbf4d] + Codecs v0.5.0
#   [3da002f7] + ColorTypes v0.8.0
#   [c3611d14] + ColorVectorSpace v0.7.1
#   [5ae59095] + Colors v0.9.6
#   [bbf7d656] + CommonSubexpressions v0.2.0
#   [34da2185] + Compat v2.2.0
#   [a81c6b42] + Compose v0.7.3
#   [ed09eef8] + ComputationalResources v0.3.0
#   [8f4d0f93] + Conda v1.3.0
#   [d38c429a] + Contour v0.5.1
#   [150eb455] + CoordinateTransformations v0.5.0
#   [7ad07ef1] + CoupledFields v0.1.0
#   [dc8bdbbb] + CustomUnitRanges v0.2.0
#   [9a962f9c] + DataAPI v1.1.0
#   [a93c6f00] + DataFrames v0.19.4
#   [864edb3b] + DataStructures v0.17.3
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [2b5f629d] + DiffEqBase v6.4.1
#   [01453d9d] + DiffEqDiffTools v1.3.0
#   [163ba53b] + DiffResults v0.0.4
#   [b552c78f] + DiffRules v0.0.10
#   [b4f34e82] + Distances v0.8.2
#   [aaf54ef3] + DistributedArrays v0.6.4
#   [31c24e10] + Distributions v0.21.3
#   [ffbed154] + DocStringExtensions v0.8.1
#   [e1f3b4f0] + DocumentFunction v0.5.1
#   [e30172f5] + Documenter v0.23.4
#   [997ab1e6] + DocumenterMarkdown v0.2.0
#   [d4d017d3] + ExponentialUtilities v1.5.1
#   [4f61f5a4] + FFTViews v0.3.0
#   [7a1cc6ca] + FFTW v1.0.1
#   [5789e2e9] + FileIO v1.0.7
#   [1a297f60] + FillArrays v0.7.4
#   [53c48c17] + FixedPointNumbers v0.6.1
#   [186bb1d3] + Fontconfig v0.3.0
#   [f6369f11] + ForwardDiff v0.10.3
#   [069b7b12] + FunctionWrappers v1.0.0
#   [de31a74c] + FunctionalCollections v0.5.0
#   [c91e804a] + Gadfly v1.0.1
#   [01680d73] + GenericSVD v0.2.2
#   [0ef565a4] + Geodesy v0.5.0
#   [a2bd30eb] + Graphics v0.4.0
#   [f67ccb44] + HDF5 v0.12.4
#   [cd3eb016] + HTTP v0.8.6
#   [a1b4810d] + Hexagons v0.2.0
#   [9fb69e20] + Hiccup v0.2.2
#   [bbac6d45] + IdentityRanges v0.3.0
#   [2803e5a7] + ImageAxes v0.6.1
#   [a09fc81d] + ImageCore v0.8.5
#   [51556ac3] + ImageDistances v0.2.4
#   [6a3955dd] + ImageFiltering v0.6.5
#   [bc367c6b] + ImageMetadata v0.7.2
#   [787d08f9] + ImageMorphology v0.2.4
#   [4e3cecfd] + ImageShow v0.2.0
#   [02fcd773] + ImageTransformations v0.8.0
#   [916415d5] + Images v0.18.0
#   [9b13fd28] + IndirectArrays v0.5.0
#   [d25df0c9] + Inflate v0.1.1
#   [83e8ac13] + IniFile v0.5.0
#   [a98d9a8b] + Interpolations v0.12.2
#   [8197267c] + IntervalSets v0.3.2
#   [41ab1584] + InvertedIndices v1.0.0
#   [b6b21f68] + Ipopt v0.6.1
#   [c8e1da08] + IterTools v1.2.0
#   [42fd0dbc] + IterativeSolvers v0.8.1
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [4138dd39] + JLD v0.9.1
#   [033835bb] + JLD2 v0.1.3
#   [97c1335a] + JSExpr v0.5.1
#   [682c06a0] + JSON v0.21.0
#   [4076af6c] + JuMP v0.20.1
#   [e5e0dc1b] + Juno v0.7.2
#   [5ab0869b] + KernelDensity v0.5.1
#   [6133562b] + Kriging v0.4.0
#   [8ac3fa9e] + LRUCache v1.0.2
#   [b964fa9f] + LaTeXStrings v1.0.3
#   [50d2b5c4] + Lazy v0.13.2
#   [5078a376] + LazyArrays v0.12.3
#   [1b4a561d] + LegacyStrings v0.4.1
#   [093fc24a] + LightGraphs v1.3.0
#   [d3d80556] + LineSearches v7.0.1
#   [bae27b42] + LoadTensorDecompositions v0.1.0
#   [4345ca2d] + Loess v0.5.0
#   [2fda8390] + LsqFit v0.8.1
#   [10e44e05] + MATLAB v0.7.3
#   [1914dd2f] + MacroTools v0.5.1
#   [d6bdc55b] + Mads v0.7.6
#   [dbb5928d] + MappedArrays v0.2.2
#   [b8f27783] + MathOptInterface v0.9.6
#   [fdba3010] + MathProgBase v0.7.7
#   [a3b82374] + MatrixFactorizations v0.2.0
#   [739be429] + MbedTLS v0.7.0
#   [442fdcdd] + Measures v0.3.0
#   [e89f7d12] + Media v0.5.0
#   [b1909ce5] + MetaProgTools v0.5.0
#   [e1d29d7a] + Missings v0.4.3
#   [46d2c3a1] + MuladdMacro v0.2.1
#   [6f286f6a] + MultivariateStats v0.7.0
#   [ffc61752] + Mustache v0.5.13
#   [a975b10e] + Mux v0.7.0
#   [d41bc354] + NLSolversBase v7.5.0
#   [76087f3c] + NLopt v0.5.1
#   [2774e3e8] + NLsolve v4.1.0
#   [6ef6ca0d] + NMF v0.4.0
#   [e40cd9e2] + NMFk v0.1.8
#   [77ba4419] + NaNMath v0.3.2
#   [b8a86587] + NearestNeighbors v0.4.3
#   [510215fc] + Observables v0.2.3
#   [6fe1bfb0] + OffsetArrays v0.11.1
#   [429524aa] + Optim v0.19.3
#   [87e2bd06] + OptimBase v2.0.0
#   [bac558e1] + OrderedCollections v1.1.0
#   [1dea7af3] + OrdinaryDiffEq v5.17.2
#   [90014a1f] + PDMats v0.9.10
#   [5432bcbf] + PaddedViews v0.4.2
#   [d96e819e] + Parameters v0.12.0
#   [69de0a69] + Parsers v0.3.7
#   [fa939f87] + Pidfile v1.1.0
#   [a03496cd] + PlotlyBase v0.3.0
#   [f0f68f2c] + PlotlyJS v0.13.0
#   [2dfb63ee] + PooledArrays v0.5.2
#   [85a6dd25] + PositiveFactorizations v0.2.2
#   [27ebfcd6] + Primes v0.4.0
#   [92933f4c] + ProgressMeter v1.1.0
#   [438e738f] + PyCall v1.91.2
#   [d330b81b] + PyPlot v2.8.2
#   [1fd47b50] + QuadGK v2.0.3
#   [dca85d43] + QuartzImageIO v0.6.0
#   [b3c3ace0] + RangeArrays v0.3.1
#   [c84ed2f1] + Ratios v0.3.1
#   [3cdcf5f2] + RecipesBase v0.7.0
#   [731186ca] + RecursiveArrayTools v1.0.2
#   [f2c3362d] + RecursiveFactorization v0.1.0
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v0.5.2
#   [afbf81f7] + ReusableFunctions v0.5.2
#   [79098fc4] + Rmath v0.5.0
#   [27aeedcb] + RobustPmap v0.5.0
#   [f2b01f46] + Roots v0.8.3
#   [6038ab10] + Rotations v0.12.0
#   [22bb73d7] + SVR v0.5.1
#   [992d4aef] + Showoff v0.3.1
#   [699a6c99] + SimpleTraits v0.9.1
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [47a9eef4] + SparseDiffTools v0.9.1
#   [d4ead438] + SpatialIndexing v0.1.2
#   [276daf66] + SpecialFunctions v0.7.2
#   [90137ffa] + StaticArrays v0.11.1
#   [2913bbd2] + StatsBase v0.32.0
#   [4c63d2b9] + StatsFuns v0.8.0
#   [5e0ebb24] + Strided v0.3.3
#   [fd094767] + Suppressor v0.1.1
#   [3783bdb8] + TableTraits v1.0.0
#   [bd369af6] + Tables v0.2.11
#   [04ed911b] + TensorDecompositions v1.0.0
#   [6aa20fa7] + TensorOperations v1.3.1
#   [9c690861] + TensorToolbox v1.0.1
#   [06e1c1a7] + TiledIteration v0.2.3
#   [0796e94c] + Tokenize v0.5.6
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [a2a6695c] + TreeViews v0.3.0
#   [9d95972d] + TupleTools v1.2.0
#   [30578b45] + URIParser v0.4.0
#   [81def892] + VersionParsing v1.1.3
#   [19fa3120] + VertexSafeGraphs v0.1.0
#   [0f1e0344] + WebIO v0.8.11
#   [104b5d7c] + WebSockets v1.5.2
#   [cc8bc4a8] + Widgets v0.6.2
#   [efce3f68] + WoodburyMatrices v0.4.1
#   [ddb6d928] + YAML v0.3.2
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [7b1f6079] + FileWatching
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [9abbd945] + Profile
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [1a1011a3] + SharedArrays
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
# Mads: Model Analysis & Decision Support
# ====
#
#     ___      ____            ____    ____              ______
#    /   \    /    \          /    |  |    \            /  __  \
#   |     \  /     |         /     |  |     \          /  /  \__\
#   |  |\  \/  /|  |        /      |  |      \        |  |
#   |  | \    / |  |       /  /|   |  |   |\  \        \  \______.
#   |  |  \__/  |  |      /  / |   |  |   | \  \        \_______  \
#   |  |        |  |     /  /  |   |  |   |  \  \               \  \
#   |  |        |  |    /  /===|   |  |   |___\  \    __.        |  |
#   |  |        |  |   /  /    |   |  |           \   \  \______/  /
#   |__|        |__|  /__/     |___|  |____________\   \__________/
#
# MADS is an integrated high-performance computational framework for data- and model-based analyses.
# MADS can perform: Sensitivity Analysis, Parameter Estimation, Model Inversion and Calibration, Uncertainty Quantification, Model Selection and Model Averaging, Model Reduction and Surrogate Modeling, Machine Learning, Decision Analysis and Support.
